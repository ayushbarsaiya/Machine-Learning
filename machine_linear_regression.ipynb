# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_table(r"C:\Users\hp\Downloads\machine.data",delimiter=',')

# %%
df
# Out:
#     vendor name          Model  MYCT  NMIN   NMAX  CACH  CHMIN  CHMAX  PRP  \
# 0       adviser          32/60   125   256   6000   256     16    128  198
# 1        amdahl         470v/7    29  8000  32000    32      8     32  269
# 2        amdahl        470v/7a    29  8000  32000    32      8     32  220
# 3        amdahl        470v/7b    29  8000  32000    32      8     32  172
# 4        amdahl        470v/7c    29  8000  16000    32      8     16  132
# ..          ...            ...   ...   ...    ...   ...    ...    ...  ...
# 204      sperry           80/8   124  1000   8000     0      1      8   42
# 205      sperry  90/80-model-3    98  1000   8000    32      2      8   46
# 206      sratus             32   125  2000   8000     0      2     14   52
# 207        wang         vs-100   480   512   8000    32      0      0   67
# 208        wang          vs-90   480  1000   4000     0      0      0   45
#
#      ERP
# 0    199
# 1    253
# 2    253
# 3    253
# 4    132
# ...

# %%
sns.heatmap(df.isnull())
# there is not any null values
# Out:
# <AxesSubplot:>

# %%
df.duplicated().sum()
# not any duplicate value
# Out:
# 0

# %%
df.columns
# Out:
# Index(['vendor name', 'Model', 'MYCT', 'NMIN', 'NMAX', 'CACH', 'CHMIN',
#        'CHMAX', 'PRP', 'ERP'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   vendor name  209 non-null    object
#  1   Model        209 non-null    object
#  2   MYCT         209 non-null    int64
#  3   NMIN         209 non-null    int64
#  4   NMAX         209 non-null    int64
#  5   CACH         209 non-null    int64
#  6   CHMIN        209 non-null    int64
#  7   CHMAX        209 non-null    int64
#  8   PRP          209 non-null    int64
#  9   ERP          209 non-null    int64
# dtypes: int64(8), object(2)
# memory usage: 16.5+ KB

# %%
df.describe()
# Out:
#               MYCT          NMIN          NMAX        CACH       CHMIN  \
# count   209.000000    209.000000    209.000000  209.000000  209.000000
# mean    203.822967   2867.980861  11796.153110   25.205742    4.698565
# std     260.262926   3878.742758  11726.564377   40.628722    6.816274
# min      17.000000     64.000000     64.000000    0.000000    0.000000
# 25%      50.000000    768.000000   4000.000000    0.000000    1.000000
# 50%     110.000000   2000.000000   8000.000000    8.000000    2.000000
# 75%     225.000000   4000.000000  16000.000000   32.000000    6.000000
# max    1500.000000  32000.000000  64000.000000  256.000000   52.000000
#
#             CHMAX          PRP          ERP
# count  209.000000   209.000000   209.000000
# mean    18.267943   105.622010    99.330144
# std     25.997318   160.830733   154.757102
# min      0.000000     6.000000    15.000000
# 25%      5.000000    27.000000    28.000000
# 50%      8.000000    50.000000    45.000000
# ...

# %%
df.corr()
# Out:
#            MYCT      NMIN      NMAX      CACH     CHMIN     CHMAX       PRP  \
# MYCT   1.000000 -0.335642 -0.378561 -0.321000 -0.301090 -0.250502 -0.307099
# NMIN  -0.335642  1.000000  0.758157  0.534729  0.517189  0.266907  0.794931
# NMAX  -0.378561  0.758157  1.000000  0.537990  0.560513  0.527246  0.863004
# CACH  -0.321000  0.534729  0.537990  1.000000  0.582245  0.487846  0.662641
# CHMIN -0.301090  0.517189  0.560513  0.582245  1.000000  0.548281  0.608903
# CHMAX -0.250502  0.266907  0.527246  0.487846  0.548281  1.000000  0.605209
# PRP   -0.307099  0.794931  0.863004  0.662641  0.608903  0.605209  1.000000
# ERP   -0.288396  0.819292  0.901202  0.648620  0.610580  0.592156  0.966472
#
#             ERP
# MYCT  -0.288396
# NMIN   0.819292
# NMAX   0.901202
# CACH   0.648620
# CHMIN  0.610580
# CHMAX  0.592156
# PRP    0.966472
# ERP    1.000000

# %%
sns.pairplot(df)

# %%
new_df=df.drop(["vendor name","Model"],axis=1)

# %%
sns.boxplot(x=df["MYCT"])
# Out:
# <AxesSubplot:xlabel='MYCT'>

# %%
sns.distplot(df["MYCT"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MYCT', ylabel='Density'>

# %%
fig, axs = plt.subplots(2, 4, figsize=(20,10))
for i, ax in enumerate(axs.flat):
    ax.boxplot(new_df.iloc[:,i])
    ax.set_title(new_df.columns[i], fontsize=20, fontweight='bold')

# %%
fig, axs = plt.subplots(2, 4, figsize=(20,10))
sns.histplot(df["MYCT"],ax=axs[0,0],kde=True)
sns.histplot(df["NMIN"],ax=axs[0,1],kde=True)
sns.histplot(df["NMAX"],ax=axs[0,2],kde=True)
sns.histplot(df["CACH"],ax=axs[0,3],kde=True)
sns.histplot(df["CHMIN"],ax=axs[1,0],kde=True)
sns.histplot(df["CHMAX"],ax=axs[1,1],kde=True)
sns.histplot(df["PRP"],ax=axs[1,2],kde=True)
sns.histplot(df["ERP"],ax=axs[1,3])
# Out:
# <AxesSubplot:xlabel='ERP', ylabel='Count'>

# %%
fig, axs = plt.subplots(2, 4, figsize=(20,10))
sns.kdeplot(df["MYCT"],ax=axs[0,0])
sns.kdeplot(df["NMIN"],ax=axs[0,1])
sns.kdeplot(df["NMAX"],ax=axs[0,2])
sns.kdeplot(df["CACH"],ax=axs[0,3])
sns.kdeplot(df["CHMIN"],ax=axs[1,0])
sns.kdeplot(df["CHMAX"],ax=axs[1,1])
sns.kdeplot(df["PRP"],ax=axs[1,2])
sns.kdeplot(df["ERP"],ax=axs[1,3])
# Out:
# <AxesSubplot:xlabel='ERP', ylabel='Density'>

# %% [markdown]
# # data is not normally distributed, it is skewed than we apply iqr formula

# %%
Max=df["MYCT"].max()
Min=df["MYCT"].min()
Mean=df["MYCT"].mean()
STD=df["MYCT"].std()
print("MAX: ",Max)
print("Min: ",Min)
print("Mean: ",Mean)
print("STD: ",STD)
# Out:
# MAX:  1500
# Min:  17
# Mean:  203.82296650717703
# STD:  260.2629259496057

# %% [markdown]
# # iqr formula,
# # lower_limit=q1-1.5*iqr
# # upper_limit=q3+1.5*iqr

# %%
q1=df["MYCT"].quantile(0.25)
q3=df["MYCT"].quantile(0.75)
iqr=q3-q1
print("Q1: ",q1)
print("Q3: ",q3)
print("IQR: ",iqr)
# Out:
# Q1:  50.0
# Q3:  225.0
# IQR:  175.0

# %%
df["MYCT"].describe()
# Out:
# count     209.000000
# mean      203.822967
# std       260.262926
# min        17.000000
# 25%        50.000000
# 50%       110.000000
# 75%       225.000000
# max      1500.000000
# Name: MYCT, dtype: float64

# %%
lower_limit=q1-1.5*(iqr)
lower_limit
# Out:
# -212.5

# %%
upper_limit=q3+1.5*(iqr)
upper_limit
# Out:
# 487.5

# %%
plt.boxplot(df["MYCT"])
plt.show()

# %%
MYCT_outlier=df[df["MYCT"]>upper_limit]
MYCT_outlier
# Out:
#     vendor name          Model  MYCT  NMIN  NMAX  CACH  CHMIN  CHMAX  PRP  ERP
# 46          dec     microvax-1   810   512   512     8      1      1   18   18
# 47          dec     vax:11/730   810  1000  5000     0      1      1   20   28
# 50           dg  eclipse:c/350   700   384  8000     0      1      1   24   34
# 51           dg  eclipse:m/600   700   256  2000     0      1      1   24   19
# 57    formation      f4000/100   800   256  8000     0      1      4   12   34
# 58    formation      f4000/200   800   256  8000     0      1      4   14   34
# 59    formation    f4000/200ap   800   256  8000     0      1      4   20   34
# 60    formation      f4000/300   800   256  8000     0      1      4   16   34
# 61    formation    f4000/300ap   800   256  8000     0      1      4   22   34
# 102         ibm           38/3  1100   512  1500     0      1      1    7   18
# 103         ibm           38/4  1100   768  2000     0      1      1   13   20
# ...

# %%
MYCT_outlier.shape[0]
# Out:
# 20

# %%
# similarly for more columns

# %% [markdown]
# # Trimming

# %%
df_T=df[(df["MYCT"]<upper_limit)&(df["MYCT"]>lower_limit)]
df_T
# Out:
#     vendor name          Model  MYCT  NMIN   NMAX  CACH  CHMIN  CHMAX  PRP  \
# 0       adviser          32/60   125   256   6000   256     16    128  198
# 1        amdahl         470v/7    29  8000  32000    32      8     32  269
# 2        amdahl        470v/7a    29  8000  32000    32      8     32  220
# 3        amdahl        470v/7b    29  8000  32000    32      8     32  172
# 4        amdahl        470v/7c    29  8000  16000    32      8     16  132
# ..          ...            ...   ...   ...    ...   ...    ...    ...  ...
# 204      sperry           80/8   124  1000   8000     0      1      8   42
# 205      sperry  90/80-model-3    98  1000   8000    32      2      8   46
# 206      sratus             32   125  2000   8000     0      2     14   52
# 207        wang         vs-100   480   512   8000    32      0      0   67
# 208        wang          vs-90   480  1000   4000     0      0      0   45
#
#      ERP
# 0    199
# 1    253
# 2    253
# 3    253
# 4    132
# ...

# %%
df_T.shape[0]
# Out:
# 189

# %% [markdown]
# # Capping

# %%
df_C=np.where(df["MYCT"]>upper_limit,upper_limit,np.where(df["MYCT"]<lower_limit,lower_limit,df["MYCT"]))
df_C
# Out:
# array([125. ,  29. ,  29. ,  29. ,  29. ,  26. ,  23. ,  23. ,  23. ,
#         23. , 400. , 400. ,  60. ,  50. , 350. , 200. , 167. , 143. ,
#        143. , 110. , 143. , 143. , 143. , 110. , 320. , 320. , 320. ,
#        320. , 320. , 320. ,  25. ,  25. ,  50. ,  50. ,  56. ,  64. ,
#         50. ,  50. ,  50. ,  50. ,  50. ,  50. ,  50. ,  50. , 133. ,
#        133. , 487.5, 487.5, 320. , 200. , 487.5, 487.5, 140. , 200. ,
#        110. , 110. , 220. , 487.5, 487.5, 487.5, 487.5, 487.5, 125. ,
#         75. ,  75. ,  75. ,  90. , 105. , 105. , 105. ,  75. ,  75. ,
#        175. , 300. , 300. , 300. , 300. , 300. , 300. , 180. , 330. ,
#        300. , 300. , 330. , 330. , 140. , 140. , 140. , 140. , 140. ,
#        140. , 140. , 140. ,  57. ,  57. ,  26. ,  26. ,  26. ,  26. ,
#        480. , 203. , 115. , 487.5, 487.5, 487.5, 400. , 400. , 487.5,
#        487.5, 487.5, 487.5, 487.5, 225. , 225. , 180. , 185. , 180. ,
# ...

# %%
df_C.shape[0]
# Out:
# 209

# %%
df
# Out:
#     vendor name          Model  MYCT  NMIN   NMAX  CACH  CHMIN  CHMAX  PRP  \
# 0       adviser          32/60   125   256   6000   256     16    128  198
# 1        amdahl         470v/7    29  8000  32000    32      8     32  269
# 2        amdahl        470v/7a    29  8000  32000    32      8     32  220
# 3        amdahl        470v/7b    29  8000  32000    32      8     32  172
# 4        amdahl        470v/7c    29  8000  16000    32      8     16  132
# ..          ...            ...   ...   ...    ...   ...    ...    ...  ...
# 204      sperry           80/8   124  1000   8000     0      1      8   42
# 205      sperry  90/80-model-3    98  1000   8000    32      2      8   46
# 206      sratus             32   125  2000   8000     0      2     14   52
# 207        wang         vs-100   480   512   8000    32      0      0   67
# 208        wang          vs-90   480  1000   4000     0      0      0   45
#
#      ERP
# 0    199
# 1    253
# 2    253
# 3    253
# 4    132
# ...

# %%
NMIN_lower_limit=df["NMIN"].quantile(0.25)-1.5*(df["NMIN"].quantile(0.75)-df["NMIN"].quantile(0.25))
NMIN_upper_limit=df["NMIN"].quantile(0.75)+1.5*(df["NMIN"].quantile(0.75)-df["NMIN"].quantile(0.25))
print("NMIN_lower_limit",NMIN_lower_limit)
print("NMIN_upper_limit",NMIN_upper_limit)
# Out:
# NMIN_lower_limit -4080.0
# NMIN_upper_limit 8848.0

# %%
plt.boxplot(df["NMIN"])
plt.show()

# %%
NMIN_outlier=df[(df["NMIN"]>NMIN_upper_limit) |(df["NMIN"]<NMIN_lower_limit)] 
NMIN_outlier
# Out:
#     vendor name        Model  MYCT   NMIN   NMAX  CACH  CHMIN  CHMAX   PRP  \
# 6        amdahl     580-5840    23  16000  32000    64     16     32   367
# 7        amdahl     580-5850    23  16000  32000    64     16     32   489
# 8        amdahl     580-5860    23  16000  64000    64     16     32   636
# 9        amdahl     580-5880    23  32000  64000   128     32     64  1144
# 95          ibm         3081    26  16000  32000    64     16     24   465
# 96          ibm       3081:d    26  16000  32000    64      8     24   465
# 153         nas  as/9000-dpc    38  16000  32000   128     16     32   510
# 156         nas      as/9060    30  16000  32000   256     16     24   510
#
#       ERP
# 6     381
# 7     381
# 8     749
# 9    1238
# 95    361
# 96    350
# 153   426
# 156   603

# %%
NMAX_lower_limit=df["NMAX"].quantile(0.25)-1.5*(df["NMAX"].quantile(0.75)-df["NMAX"].quantile(0.25))
NMAX_upper_limit=df["NMAX"].quantile(0.75)+1.5*(df["NMAX"].quantile(0.75)-df["NMAX"].quantile(0.25))
print("NMAX_lower_limit",NMAX_lower_limit)
print("NMAX_upper_limit",NMAX_upper_limit)
# Out:
# NMAX_lower_limit -14000.0
# NMAX_upper_limit 34000.0

# %%
NMAX_outlier=df[(df["NMAX"]>NMAX_upper_limit) |(df["NMAX"]<NMAX_lower_limit)] 
NMAX_outlier
# Out:
#     vendor name     Model  MYCT   NMIN   NMAX  CACH  CHMIN  CHMAX   PRP   ERP
# 8        amdahl  580-5860    23  16000  64000    64     16     32   636   749
# 9        amdahl  580-5880    23  32000  64000   128     32     64  1144  1238
# 198      sperry   1100/93    30   8000  64000    96     12    176   915   919
# 199      sperry   1100/94    30   8000  64000   128     12    176  1150   978

# %%
plt.boxplot(df["NMAX"])
plt.show()

# %% [markdown]
# # Linear Regression

# %%
df.Model.nunique()
# Out:
# 209

# %%
df.drop(["Model"],axis=1,inplace=True)

# %%
df
# Out:
#      MYCT  NMIN   NMAX  CACH  CHMIN  CHMAX  PRP  ERP  vendor name_adviser  \
# 0     125   256   6000   256     16    128  198  199                    1
# 1      29  8000  32000    32      8     32  269  253                    0
# 2      29  8000  32000    32      8     32  220  253                    0
# 3      29  8000  32000    32      8     32  172  253                    0
# 4      29  8000  16000    32      8     16  132  132                    0
# ..    ...   ...    ...   ...    ...    ...  ...  ...                  ...
# 204   124  1000   8000     0      1      8   42   37                    0
# 205    98  1000   8000    32      2      8   46   50                    0
# 206   125  2000   8000     0      2     14   52   41                    0
# 207   480   512   8000    32      0      0   67   47                    0
# 208   480  1000   4000     0      0      0   45   25                    0
#
#      vendor name_amdahl  ...  vendor name_microdata  vendor name_nas  \
# ...

# %%
df=pd.get_dummies(df)

# %%
df
# Out:
#      MYCT  NMIN   NMAX  CACH  CHMIN  CHMAX  PRP  ERP  vendor name_adviser  \
# 0     125   256   6000   256     16    128  198  199                    1
# 1      29  8000  32000    32      8     32  269  253                    0
# 2      29  8000  32000    32      8     32  220  253                    0
# 3      29  8000  32000    32      8     32  172  253                    0
# 4      29  8000  16000    32      8     16  132  132                    0
# ..    ...   ...    ...   ...    ...    ...  ...  ...                  ...
# 204   124  1000   8000     0      1      8   42   37                    0
# 205    98  1000   8000    32      2      8   46   50                    0
# 206   125  2000   8000     0      2     14   52   41                    0
# 207   480   512   8000    32      0      0   67   47                    0
# 208   480  1000   4000     0      0      0   45   25                    0
#
#      vendor name_amdahl  ...  vendor name_microdata  vendor name_nas  \
# ...

# %%
X=df.drop(["ERP"],axis=1)
X
# Out:
#      MYCT  NMIN   NMAX  CACH  CHMIN  CHMAX  PRP  vendor name_adviser  \
# 0     125   256   6000   256     16    128  198                    1
# 1      29  8000  32000    32      8     32  269                    0
# 2      29  8000  32000    32      8     32  220                    0
# 3      29  8000  32000    32      8     32  172                    0
# 4      29  8000  16000    32      8     16  132                    0
# ..    ...   ...    ...   ...    ...    ...  ...                  ...
# 204   124  1000   8000     0      1      8   42                    0
# 205    98  1000   8000    32      2      8   46                    0
# 206   125  2000   8000     0      2     14   52                    0
# 207   480   512   8000    32      0      0   67                    0
# 208   480  1000   4000     0      0      0   45                    0
#
#      vendor name_amdahl  vendor name_apollo  ...  vendor name_microdata  \
# ...

# %%
y=df["ERP"]

# %% [markdown]
# # train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=7)

# %%
X_train
# Out:
#      MYCT  NMIN   NMAX  CACH  CHMIN  CHMAX  PRP  vendor name_adviser  \
# 128    50  2000  16000    24      1      6   70                    0
# 195    50  2000  32000    48     26     52  208                    0
# 99    480    96    512     0      1      1    6                    0
# 97     26  8000  32000     0      8     24  277                    0
# 14    350    64     64     0      1      4   10                    0
# ..    ...   ...    ...   ...    ...    ...  ...                  ...
# 151    40  8000  32000    64      8     24  277                    0
# 67    105   256   2000     0      3     10   26                    0
# 25    320   512   2000     4      1      3   69                    0
# 196    50  2000  32000   112     52    104  307                    0
# 175   250  1000  16000     1      1      8   50                    0
#
#      vendor name_amdahl  vendor name_apollo  ...  vendor name_microdata  \
# ...

# %%
X_test.shape[0]
# Out:
# 42

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn import metrics
print("MAE: ",metrics.mean_absolute_error(y_test,y_pred))
print("MSE: ",metrics.mean_squared_error(y_test,y_pred))
print("RMSE: ",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE:  27.51097194894216
# MSE:  3273.6309040260726
# RMSE:  57.215652613826514

# %%
# model.score(y_test,y_pred)
model.score(X_test,y_test)
# Out:
# 0.9286945940539308

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9286945940539308

# %% [markdown]
# # 92.86% accuracy of the model

# %% [markdown]
# # Report

# %%
# Estimated Relative Performance (ERP) is based on many feature such as NMIN,NMAX,CACH,PRP etc.
# When The value PRP,NMAX is incresing than ERP is increasing.
